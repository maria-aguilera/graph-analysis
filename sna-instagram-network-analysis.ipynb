# %% [markdown]
# # **Instagram Network Analysis** ☎**SNA Group Assignment**
#
# <p align="left">
# <img src ="https://thumbs.dreamstime.com/b/social-media-logos-facebook-twitter-instagram-youtube-flickr-vector-pg-transparent-background-high-resolution-linkedin-googleplus-210670466.jpgl" width ="800px" height ="200px">
# </p>

# %% [markdown]
# # **Table of Contents**

# %% [markdown]
# >[Instagram Network Analysis ☎SNA Group Assignment](#scrollTo=PWFGQ5-FYDGQ)
#
# >[Table of Contents](#scrollTo=gbZu_GksNYzI)
#
# >>[Introduction](#scrollTo=NaFM2-XSt_MW)
#
# >>[Data Gathering](#scrollTo=jC_sW1rNujZl)
#
# >>[Setting up the Environment](#scrollTo=QOK0vloOMQeB)
#
# >>>>[Setup for Working in Colab](#scrollTo=43d378d0)
#
# >>>>[Installing required libraries](#scrollTo=9o63IvmLMtMK)
#
# >>>>[Setting up Working Directory](#scrollTo=1MYB6EKEM50G)
#
# >>>>[Importing necessary libraries](#scrollTo=rEyRfBFXNKCY)
#
# >>[Understanding the data](#scrollTo=QhpSfA0LXiu4)
#
# >>>>[Variable Descriptions of Vertices Data Set](#scrollTo=nU62hzH9Z596)
#
# >>>>[Analyzing the data set](#scrollTo=3YqT6h79SyAU)
#
# >>>>[Unsupervised Machine Learning Algorithim](#scrollTo=hn9tV4TvR6Kk)
#
# >>[Reducing the nodes and edges and creating the graph](#scrollTo=66afd3af)
#
# >>[Analyzing the Network](#scrollTo=1NKuq2HVjntm)
#
# >>>[How many users are not following and are not being followed by anyone from the reduced list?](#scrollTo=d1858695)
#
# >>>[Creating Graphs](#scrollTo=1eb30f66)
#
# >>>[Centrality Measures](#scrollTo=5e1d30b2)
#
# >>>>[(In & Out) Degree Centrality](#scrollTo=werLwIBkmg92)
#
# >>>>[Closeness Centrality](#scrollTo=e98v9mf9tVnU)
#
# >>>>[Eigenvector Centrality](#scrollTo=5Q9DMsJ7uUDy)
#
# >>>>[Betweenness Centrality](#scrollTo=206e5ec7)
#
# >>>[Diameter](#scrollTo=ce196fd2)
#
# >>>[Average path length](#scrollTo=5d96bcd8)
#
# >>>[Density](#scrollTo=qKQRdZNjncN-)
#
# >>>[Transitivity](#scrollTo=eYLe2_janziO)
#
# >>>[Reciprocity](#scrollTo=e8zSY_bQpjDv)
#
# >>>[Visual Analysis](#scrollTo=mG7axYIdik4W)
#
# >>>[Accounts not followed by anyone](#scrollTo=0151c4aa)
#
# >>>[Accounts not following anyone](#scrollTo=eae1782f)
#
# >>>[PageRank](#scrollTo=c94dddfe)
#
# >>[Community Detection](#scrollTo=NG6pQZNuJ_Jr)
#
# >>[Information Diffusion](#scrollTo=8974bc64)
#
# >>>[Creating Epidemic Model Using SIR](#scrollTo=a4632d07)
#
# >>>[Link Prediction](#scrollTo=bf299027)

# %% [markdown]
# ## Introduction
# Our client is a shoe store called "Botas". It's main goal is to increase sales by a better advertisement,
# so they decided to find more platforms to advertise their shoes and stopped by the Instagram.
# They hired us as data analysts to find the best possible influencer in the city to buy an instagram post from them.

# %% [markdown]
# ## Data Gathering
# We started our work with data gathering.
# We found the instagram users with following hashtags: #iloveshoes, #niceshoes, #shoes
# and gathered the data about nodes, edges and following features: num_posts, num_followers, num_following,
# engagement_grade, engagement_rate, followers_growth, outsiders

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# #### Setup for Working in Colab

# %% [markdown]
# #### Installing required libraries

# %%
! pip install python-igraph
! apt-get install libcairo2-dev libjpeg-dev libgif-dev
! pip install pycairo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-igraph
#   Downloading python-igraph-0.9.11.tar.gz (9.5 kB)
# Collecting igraph==0.9.11
#   Downloading igraph-0.9.11-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 6.5 MB/s
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: python-igraph
#   Building wheel for python-igraph (setup.py) ... done
#   Created wheel for python-igraph: filename=python_igraph-0.9.11-py3-none-any.whl size=9074 sha256=3e945d1be9e4cce38c456cffbc27f76cf13af481ba4ea5a0c7dba5e84a7147f3
#   Stored in directory: /root/.cache/pip/wheels/7d/e4/0c/0c83f70bd0b99ce8aea47a21f8e52502169e7dd17808d12f30
# Successfully built python-igraph
# Installing collected packages: texttable, igraph, python-igraph
# Successfully installed igraph-0.9.11 python-igraph-0.9.11 texttable-1.6.4
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# libgif-dev is already the newest version (5.1.4-2ubuntu0.1).
# libgif-dev set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libcairo-script-interpreter2 libpixman-1-dev libxcb-shm0-dev
# Suggested packages:
#   libcairo2-doc
# The following NEW packages will be installed:
#   libcairo-script-interpreter2 libcairo2-dev libpixman-1-dev libxcb-shm0-dev
# 0 upgraded, 4 newly installed, 0 to remove and 49 not upgraded.
# Need to get 930 kB of archives.
# After this operation, 3,986 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]
# Fetched 930 kB in 1s (1,531 kB/s)
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# (Reading database ... 155639 files and directories currently installed.)
# Preparing to unpack .../libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycairo
#   Downloading pycairo-1.21.0.tar.gz (340 kB)
#      |████████████████████████████████| 340 kB 7.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: pycairo
#   Building wheel for pycairo (PEP 517) ... done
#   Created wheel for pycairo: filename=pycairo-1.21.0-cp37-cp37m-linux_x86_64.whl size=286813 sha256=0d939bc335d07905720186576bb64663fd4a8f827384c95b83c77beea2eee1a9
#   Stored in directory: /root/.cache/pip/wheels/69/1e/e8/ea8e397b1bea0fcbcffad6477c5ced6550a2adc259ed400405
# Successfully built pycairo
# Installing collected packages: pycairo
# Successfully installed pycairo-1.21.0

# %% [markdown]
# #### Setting up Working Directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/SNA
# Out:
# /content/drive/MyDrive/SNA

# %% [markdown]
# #### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import networkx as nx

from igraph import *
import igraph as ig
from igraph import Graph

import seaborn as sns

from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

sns.set()

import pprint
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties
import re
import networkx as nx
import argparse
import collections
import scipy.optimize

# %% [markdown]
# ## Understanding the data
# * We have to understand the the variables of our data set in order to take any decision.
# * We import our vertices/nodes dataframe and analyze it to decide how many number of vertices we shoud keep (>74,000 vertices and 1,1 million edges was not possible due to computing power) and based on what variables. In order to do this we peform some exploratory analysis and cluster analysis.

# %%
num_vertices = None # "None" means read whole file


vertices_df = pd.read_csv('data/Instagram User Stats_final.csv',delimiter=',', nrows = num_vertices)
del vertices_df['Unnamed: 0']


print(f'Vertices data sett has {vertices_df.shape[0]} observations and {vertices_df.shape[1]-1} features.')
# Out:
# Vertices data sett has 70409 observations and 8 features.

# %%
vertices_df.head()
# Out:
#    id  pos    flr   flg      eg         er        fg       op  \
# 0   1  702    906   677  0.1891   6.070640  1.177860  14.8936
# 1   2  160    386   713  0.1950   6.260800  0.094127  16.9811
# 2   3  851  20400  3700  0.0664   0.717416  2.242440  38.2166
# 3   4   42    900  7500  0.0592   1.901230  7.643310  60.1626
# 4   5   50    486  4350  0.5112  16.409500  0.372900  61.9403
#
#                 username
# 0          LeafyEqual606
# 1        SmoggyCampus867
# 2        HonestGazebo218
# 3  FatherlyEquivalent813
# 4      LopsidedPantry359

# %% [markdown]
#  #### Variable Descriptions of Vertices Data Set
#
#
#
#
# |Variable | Description |
# |-------|-------------|
# |pos | num_vertices of posts |
# | flr | num_vertices of Followers |
# |flg | num_vertices of Following |
# |eg | Engagement grade, a scale of 1 to 12 that reflects the strength of engagement rate relative to the num_vertices of followers |
#  |er | Engagement Rate, i.e. likes+comments / followers |
# | fg | Followers growth % in a month |
# | op | Outsiders percentage %, i.e. non-followers that liked a post, divided by all unique likers |

# %%
# We change the names for easier interpretability.

vertices_df.columns = ['id',
                       'num_posts',
                       'num_followers',
                       'num_following',
                       'engagement_grade',
                       'engagement_rate',
                       'followers_growth',
                       'outsiders',
                       'username']

# %%
vertices_df.head()
# Out:
#    id  num_posts  num_followers  num_following  engagement_grade  \
# 0   1        702            906            677            0.1891
# 1   2        160            386            713            0.1950
# 2   3        851          20400           3700            0.0664
# 3   4         42            900           7500            0.0592
# 4   5         50            486           4350            0.5112
#
#    engagement_rate  followers_growth  outsiders               username
# 0         6.070640          1.177860    14.8936          LeafyEqual606
# 1         6.260800          0.094127    16.9811        SmoggyCampus867
# 2         0.717416          2.242440    38.2166        HonestGazebo218
# 3         1.901230          7.643310    60.1626  FatherlyEquivalent813
# 4        16.409500          0.372900    61.9403      LopsidedPantry359

# %% [markdown]
# #### Analyzing the data set
# * We peform exploratory data analysis to understand how to reduce our dataframe so it doesn't become a random network.

# %%
# Check types
vertices_df.dtypes
# Out:
# id                    int64
# num_posts             int64
# num_followers         int64
# num_following         int64
# engagement_grade    float64
# engagement_rate     float64
# followers_growth    float64
# outsiders           float64
# username             object
# dtype: object

# %%
# Check null values
vertices_df[vertices_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, num_posts, num_followers, num_following, engagement_grade, engagement_rate, followers_growth, outsiders, username]
# Index: []

# %%
# Create a list of attribute columns to loop over
attributes =  [x for x in vertices_df.columns if x not in ['id','username']]

# %%
len(attributes)
# Out:
# 7

# %%
# Plotting Distributions
import itertools
palette = itertools.cycle(sns.color_palette('Set2'))
plt.figure(figsize = (8,10))
for i, col in enumerate(vertices_df[attributes]):
    plt.subplot(5,2,i+1)
    sns.distplot(vertices_df[attributes][col],color=next(palette))
    plt.title(f'{col} Distribution', fontsize = 12)
    plt.tight_layout()

plt.show();

# %%
plt.subplots(figsize = (5,3.5))
sns.boxplot(data = vertices_df[attributes], orient='h', palette=sns.color_palette('hls'))
plt.title('Spread of data in Numerical Features', size = 12)
plt.xlabel('No.of Observation', size = 10)
plt.ylabel('Features', size = 10)
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.show()

# %%
# Descriptive stastitcs so we can later compare with our reduced data set
vertices_df[attributes].describe().T.round(2)
# Out:
#                     count     mean      std  min     25%     50%      75%  \
# num_posts         70409.0   201.06   612.21  0.0   12.00   44.00   160.00
# num_followers     70409.0  1347.50  9354.81  1.0  243.00  548.00  1100.00
# num_following     70409.0  1506.08  1786.14  0.0  392.00  814.00  1800.00
# engagement_grade  70409.0     0.39     0.29  0.0    0.16    0.32     0.57
# engagement_rate   70409.0    13.08    11.48  0.0    4.70    9.91    17.93
# followers_growth  70409.0     1.28     2.59 -5.0   -0.09    0.64     1.58
# outsiders         70409.0    48.51    27.23  0.0   28.16   47.06    70.45
#
#                         max
# num_posts           30200.0
# num_followers     1300000.0
# num_following        8800.0
# engagement_grade        1.0
# engagement_rate        50.0
# followers_growth       10.0
# outsiders             100.0

# %%
# Count number of zeros in all columns 
for column_name in vertices_df.columns:
    column = vertices_df[column_name]
    count = (column == 0).sum()
    print('Count of zeros in column', column_name, 'is:', count)
# Out:
# Count of zeros in column id is: 0
# Count of zeros in column num_posts is: 45
# Count of zeros in column num_followers is: 0
# Count of zeros in column num_following is: 9
# Count of zeros in column engagement_grade is: 29
# Count of zeros in column engagement_rate is: 29
# Count of zeros in column followers_growth is: 4135
# Count of zeros in column outsiders is: 5488
# Count of zeros in column username is: 0

# %%
# Finding outliers (in this case, we do NOT want to delete this)
def outlier_function(df_train, col_name):
    ''' this function detects first and third quartile and interquartile range for a given column of a dataframe
    then calculates upper and lower limits to determine outliers conservatively
    returns the number of lower and uper limit and number of outliers respectively
    '''
    first_quartile = np.percentile(np.array(df_train[col_name].tolist()), 25)
    third_quartile = np.percentile(np.array(df_train[col_name].tolist()), 75)
    IQR = third_quartile - first_quartile
                      
    upper_limit = third_quartile+(3*IQR)
    lower_limit = first_quartile-(3*IQR)
    outlier_count = 0
                      
    for value in df_train[col_name].tolist():
        if (value < lower_limit) | (value > upper_limit):
            outlier_count +=1
    return lower_limit, upper_limit, outlier_count

# %%
for col in attributes:
    if outlier_function(vertices_df, col)[2] > 0:
        print("There are {} outliers in {}".format(outlier_function(vertices_df, col)[2], col))
# Out:
# There are 5359 outliers in num_posts
# There are 3158 outliers in num_followers
# There are 3733 outliers in num_following
# There are 4477 outliers in followers_growth

# %%
# Correlation Matrix to identify potentially useful variable to reduce the number of vertices
corrmat =vertices_df[attributes].corr()
f, ax = plt.subplots(figsize = (8,6))
sns.heatmap(corrmat,vmax=0.8,square=True, center=0, annot=True, annot_kws={"size": 10}, cbar_kws={"shrink": .8},
            cmap=plt.cm.coolwarm);
plt.show()

# %%
#! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
#from pandas_profiling import ProfileReport
#profile = ProfileReport(df)
#profile

# %% [markdown]
# #### Unsupervised Machine Learning Algorithim

# %%
# https://programminghistorian.org/en/lessons/clustering-with-scikit-learn-in-python
from sklearn.preprocessing import StandardScaler as SS # z-score standardization 
from sklearn.cluster import KMeans, DBSCAN # clustering algorithms
from sklearn.decomposition import PCA # dimensionality reduction
from sklearn.metrics import silhouette_score # used as a metric to evaluate the cohesion in a cluster
from sklearn.neighbors import NearestNeighbors # for selecting the optimal eps value when using DBSCAN
import numpy as np

# plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns
from yellowbrick.cluster import SilhouetteVisualizer

# %%
def silhouettePlot(range_, data):
    '''
    we will use this function to plot a silhouette plot that helps us to evaluate the cohesion in clusters (k-means only)
    '''
    half_length = int(len(range_)/2)
    range_list = list(range_)
    fig, ax = plt.subplots(half_length, 2, figsize=(15,8))
    for _ in range_:
        kmeans = KMeans(n_clusters=_, random_state=42)
        q, mod = divmod(_ - range_list[0], 2)
        sv = SilhouetteVisualizer(kmeans, colors="yellowbrick", ax=ax[q][mod])
        ax[q][mod].set_title("Silhouette Plot with n={} Cluster".format(_))
        sv.fit(data)
    fig.tight_layout()
    fig.show()
    fig.savefig("silhouette_plot.png")

# %%
def elbowPlot(range_, data, figsize=(10,10)):
    '''
    the elbow plot function helps to figure out the right amount of clusters for a dataset
    '''
    inertia_list = []
    for n in range_:
        kmeans = KMeans(n_clusters=n, random_state=42)
        kmeans.fit(data)
        inertia_list.append(kmeans.inertia_)
        
    # plotting
    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot(111)
    sns.lineplot(y=inertia_list, x=range_, ax=ax)
    ax.set_xlabel("Cluster")
    ax.set_ylabel("Inertia")
    ax.set_xticks(list(range_))
    fig.show()
    fig.savefig("elbow_plot.png")

# %%
def findOptimalEps(n_neighbors, data):
    '''
    function to find optimal eps distance when using DBSCAN; based on this article: https://towardsdatascience.com/machine-learning-clustering-dbscan-determine-the-optimal-value-for-epsilon-eps-python-example-3100091cfbc
    '''
    neigh = NearestNeighbors(n_neighbors=n_neighbors)
    nbrs = neigh.fit(data)
    distances, indices = nbrs.kneighbors(data)
    distances = np.sort(distances, axis=0)
    distances = distances[:,1]
    plt.plot(distances)

# %%
def progressiveFeatureSelection(df, n_clusters=3, max_features=4,):
    '''
    very basic implementation of an algorithm for feature selection (unsupervised clustering); inspired by this post: https://datascience.stackexchange.com/questions/67040/how-to-do-feature-selection-for-clustering-and-implement-it-in-python
    '''
    feature_list = list(df.columns)
    selected_features = list()
    # select starting feature
    initial_feature = ""
    high_score = 0
    for feature in feature_list:
        kmeans = KMeans(n_clusters=n_clusters, random_state=42)
        data_ = df[feature]
        labels = kmeans.fit_predict(data_.to_frame())
        score_ = silhouette_score(data_.to_frame(), labels)
        print("Proposed new feature {} with score {}". format(feature, score_))
        if score_ >= high_score:
            initial_feature = feature
            high_score = score_
    print("The initial feature is {} with a silhouette score of {}.".format(initial_feature, high_score))
    feature_list.remove(initial_feature)
    selected_features.append(initial_feature)
    for _ in range(max_features-1):
        high_score = 0
        selected_feature = ""
        print("Starting selection {}...".format(_))
        for feature in feature_list:
            selection_ = selected_features.copy()
            selection_.append(feature)
            kmeans = KMeans(n_clusters=n_clusters, random_state=42)
            data_ = df[selection_]
            labels = kmeans.fit_predict(data_)
            score_ = silhouette_score(data_, labels)
            print("Proposed new feature {} with score {}". format(feature, score_))
            if score_ > high_score:
                selected_feature = feature
                high_score = score_
        selected_features.append(selected_feature)
        feature_list.remove(selected_feature)
        print("Selected new feature {} with score {}". format(selected_feature, high_score))
    return selected_features

# %%
cluster_df = vertices_df.copy()

# %%
cluster_df.drop(columns = ['id', 'username'],inplace = True)

# %%
scaler = SS()
DNP_authors_standardized = scaler.fit_transform(cluster_df)
df_standardized = pd.DataFrame(DNP_authors_standardized, columns=['num_posts', 'num_followers', 'num_following', 'engagement_grade',
       'engagement_rate', 'followers_growth', 'outsiders'])
df_standardized = df_standardized.set_index(cluster_df.index)

# %%
selected_features = progressiveFeatureSelection(df_standardized, max_features=3, n_clusters=3)
# Out:
# Proposed new feature num_posts with score 0.8988142627780683
# Proposed new feature num_followers with score 0.9855450272782712
# Proposed new feature num_following with score 0.6945903314662285
# Proposed new feature engagement_grade with score 0.6021590039365748
# Proposed new feature engagement_rate with score 0.6054004061431133
# Proposed new feature followers_growth with score 0.5485361602959146
# Proposed new feature outsiders with score 0.5550676760323034
# The initial feature is num_followers with a silhouette score of 0.9855450272782712.
# Starting selection 0...
# Proposed new feature num_posts with score 0.9169331078267804
# Proposed new feature num_following with score 0.7528962908471186
# Proposed new feature engagement_grade with score 0.6067090670643271
# Proposed new feature engagement_rate with score 0.6172367249247749
# Proposed new feature followers_growth with score 0.7539125890422174
# Proposed new feature outsiders with score 0.5634067033034522
# Selected new feature num_posts with score 0.9169331078267804
# Starting selection 1...
# Proposed new feature num_following with score 0.6983138722030645
# Proposed new feature engagement_grade with score 0.5014781132644631
# Proposed new feature engagement_rate with score 0.5083711063565761
# Proposed new feature followers_growth with score 0.6688108400455617
# Proposed new feature outsiders with score 0.4663136171471656
# Selected new feature num_following with score 0.6983138722030645

# %%
selected_features = ['num_followers', 'num_posts', 'num_following']

# %%
df_standardized_sliced = df_standardized[['num_followers', 'num_posts']]

# %%
elbowPlot(range(1,11), df_standardized_sliced)
plt.show()

# %%
silhouettePlot(range(3,9), df_standardized_sliced)
plt.show()

# %% [markdown]
# ## Reducing the nodes and edges and creating the graph

# %% [markdown]
# In order to simplify our analysis, we will take the top 5% users regarding number of posts.

# %%
percentage = 0.05

# %%
vertices_reduced = vertices_df.sort_values('num_posts', ascending = False)[0:round(len(vertices_df)*percentage)]

# %%
import igraph as ig
from igraph import Graph

# %%
g = Graph()

# %%
g.add_vertices(vertices_reduced.index)

# %%
print(g)
# Out:
# IGRAPH UN-- 3520 0 --
# + attr: name (v)

# %%
edges_df = pd.read_csv('data/Network for IC-u LT-u.txt', delimiter = ' ', names = ['Source', 'Target', 'Weight'], skiprows=[0])

# %%
# Making sure we only have the edges in our vertices reduced data frame
edges_df = edges_df[edges_df['Source'].isin(vertices_reduced.id.unique())]
edges_df = edges_df[edges_df['Target'].isin(vertices_reduced.id.unique())]

# %%
print(f"There are {len(vertices_reduced['id'].unique())} unique users in our dataset= unique nodes")
# Out:
# There are 3520 unique users in our dataset= unique nodes

# %%
reduced_df = pd.merge(vertices_reduced,edges_df,left_on ='id',right_on='Source',how = 'inner')
reduced_df= reduced_df[reduced_df['Target'].isin(vertices_reduced.id)]

# %%
reduced_df['Source'] = reduced_df['Source'].astype(int)
reduced_df['Target'] = reduced_df['Target'].astype(int)
reduced_df
# Out:
#           id  num_posts  num_followers  num_following  engagement_grade  \
# 0      52660      30200           5200           1800            0.0050
# 1      52660      30200           5200           1800            0.0050
# 2       8919      30100          50700           1600            0.0972
# 3       8919      30100          50700           1600            0.0972
# 4       8919      30100          50700           1600            0.0972
# ...      ...        ...            ...            ...               ...
# 29750  11482        846          19600           7100            0.0247
# 29751  11482        846          19600           7100            0.0247
# 29752  11482        846          19600           7100            0.0247
# 29753  35975        846           1400           5700            0.0215
# 29754  35975        846           1400           5700            0.0215
#
#        engagement_rate  followers_growth  outsiders           username  \
# 0             0.073529          0.000000    56.0000          FlatTap75
# 1             0.073529          0.000000    56.0000          FlatTap75
# 2             0.758054          0.824058    36.5463   LegalFootwear138
# 3             0.758054          0.824058    36.5463   LegalFootwear138
# 4             0.758054          0.824058    36.5463   LegalFootwear138
# ...                ...               ...        ...                ...
# 29750         0.266723          0.098619    59.2179  ThreadbareHate813
# 29751         0.266723          0.098619    59.2179  ThreadbareHate813
# 29752         0.266723          0.098619    59.2179  ThreadbareHate813
# 29753         0.690476          1.469870    35.4839    HeftyMachine470
# 29754         0.690476          1.469870    35.4839    HeftyMachine470
#
#        Source  Target    Weight
# 0       52660    7336  0.000188
# 1       52660   50246  0.000341
# 2        8919    5095  0.001229
# 3        8919    7027  0.003876
# 4        8919    8835  0.003608
# ...       ...     ...       ...
# 29750   11482   41525  0.007161
# 29751   11482   52010  0.003701
# 29752   11482   52635  0.003364
# 29753   35975     624  0.001791
# 29754   35975   41081  0.000253
#
# [29755 rows x 12 columns]

# %%
reduced_df.shape
# Out:
# (29755, 12)

# %%
vertices_reduced.rename(columns={"id": "Id", 'username': 'Label'}, inplace = True)
vertices_reduced.set_index('Id', inplace = True)
vertices_reduced.to_csv('gephi_nodes_final.csv')
vertices_reduced.head(1)
# Out:
#        num_posts  num_followers  num_following  engagement_grade  \
# Id
# 52660      30200           5200           1800             0.005
#
#        engagement_rate  followers_growth  outsiders      Label
# Id
# 52660         0.073529               0.0       56.0  FlatTap75

# %%
edges_df.set_index('Source', inplace = True)
edges_df.to_csv('gephi_edges_final.csv')

# %% [markdown]
# ## Analyzing the Network

# %% [markdown]
# ### How many users are not following and are not being followed by anyone from the reduced list?

# %%
vertices_reduced.head()
# Out:
#        num_posts  num_followers  num_following  engagement_grade  \
# Id
# 52660      30200           5200           1800            0.0050
# 8919       30100          50700           1600            0.0972
# 20432      27400         238200           7000            0.0036
# 19538      25900          22100           4900            0.0038
# 17016      22500           1200           7500            0.0001
#
#        engagement_rate  followers_growth  outsiders                  Label
# Id
# 52660         0.073529          0.000000    56.0000              FlatTap75
# 8919          0.758054          0.824058    36.5463       LegalFootwear138
# 20432         0.025609         10.000000    16.1804          MilkyThong936
# 19538         0.040975         -0.259217   100.0000      PrimaryHurdler443
# 17016         0.004630          1.309500     0.0000  GlamorousProfessor655

# %%
print(f"There are {len(vertices_reduced.index.unique()) - len(np.unique(list(reduced_df['Source'])+list(reduced_df['Target'])))} users disconnected from the network i.e. not following anyone/not being followed")
# Out:
# There are 256 users disconnected from the network i.e. not following anyone/not being followed

# %%
print(f'There are {vertices_reduced.index.nunique()} unique users i.e. nodes in our graph')
# Out:
# There are 3520 unique users i.e. nodes in our graph

# %%
print(f"Number of users that have followers {edges_df['Target'].nunique()}")
# Out:
# Number of users that have followers 3146

# %%
edges_df['edges'] = list(zip(edges_df.index, edges_df.Target))

# %%
vertices_reduced.reset_index(inplace=True)

# %%
edges_df.reset_index(inplace=True)

# %% [markdown]
# ### Creating Graphs

# %%
# %matplotlib inline

# %%
from igraph import *
import igraph as ig
import pandas as pd

# %%
g_data = Graph.DataFrame(edges=edges_df, vertices=vertices_reduced, directed=True)

# %%
summary(g_data)
# Out:
# IGRAPH DN-- 3520 29755 --
# + attr: Label (v), engagement_grade (v), engagement_rate (v), followers_growth (v), name (v), num_followers (v), num_following (v), num_posts (v), outsiders (v), Weight (e), edges (e)

# %% [markdown]
# ### Centrality Measures
#
# Who are the most important instaram users for expanding our  shoe company? Centrality measures gives you a clear idea of the importance of any nodes.
# Some users might not have a huge number of followers but still be important in the network being the connecting nodes between clusters of users.

# %%
g_data.vs["betweenness"] = g_data.vs.betweenness()
g_data.vs["closeness"] = g_data.vs.closeness()

g_data.vs['page_rank_weighted'] = g_data.personalized_pagerank(weights='Weight')
g_data.vs['page_rank'] = g_data.personalized_pagerank()

g_data.vs['transitivity'] = g_data.transitivity_local_undirected()
g_data.vs['reciprocity'] = g_data.is_mutual()

g_data.vs['is_loop'] = g_data.is_loop()

g_data.vs['in_degree'] = g_data.degree(mode='in')
g_data.vs['out_degree'] = g_data.degree(mode='out')
g_data.vs['total_degree'] = g_data.degree(mode='all')

g_data.vs['in_degree_ratio'] = pd.Series(g_data.vs['in_degree'])/pd.Series(g_data.vs['total_degree'])
g_data.vs['out_degree_ratio'] = pd.Series(g_data.vs['out_degree'])/pd.Series(g_data.vs['total_degree'])

g_data.vs['strength_weighted_in']= g_data.strength(mode='in',weights='Weight')
g_data.vs['strength_weighted_out']= g_data.strength(mode='out',weights='Weight')

g_data.vs['strength_weighted_difference'] = pd.Series(g_data.vs['strength_weighted_in']) - pd.Series(g_data.vs['strength_weighted_out'])

g_data.vs['avg_strength_weighted_in']= pd.Series(g_data.strength(mode='in',weights='Weight')) / pd.Series(g_data.degree(mode='in'))
g_data.vs['avg_strength_weighted_out']= pd.Series(g_data.strength(mode='out',weights='Weight')) / pd.Series(g_data.degree(mode='out'))
node_df = pd.DataFrame({attr: g_data.vs[attr] for attr in g_data.vertex_attributes()})
#node_df_largest = pd.DataFrame({attr: largest.vs[attr] for attr in largest.vertex_attributes()})

# %%
vertices_reduced.rename(columns={"Id": "id", 'Label': 'username'}, inplace = True)
edges_df.rename(columns={"Source": "id", 'Target': 'target'}, inplace = True)

# %%
edges_users_df = pd.merge(
    vertices_df[['id', 'username']], edges_df, how="left", on=["id"]
 )
edges_users_df = pd.merge(
    vertices_df[['id', 'username']], edges_users_df, how="left", left_on=["id"], right_on=['target']
 )
del edges_users_df['target']
edges_users_df.rename(columns={"id_x": "id_source",
                               "id_y": "id_target",
                               'target': 'Target',
                               'username_x': 'source_u',
                               'username_y': 'target_u' }, inplace = True)
edges_users_df.dropna(inplace=True)
edges_users_df['id_target'] = edges_users_df['id_target'].astype(int)

# %%
G = nx.from_pandas_edgelist(edges_users_df, source='source_u', target='target_u', edge_attr='Weight', create_using=nx.DiGraph())

# %% [markdown]
# #### (In & Out) Degree Centrality

# %% [markdown]
# **Degree**: it shows the total number of connections: follows + followers

# %%
g_data.vs["degree"]=g_data.degree(mode='all')

# %%
print(f"The node with the highest number of connections has {max(g_data.vs['degree'])} connections, i.e. the user with most followers and follows") # num_vertices of followers of greatest influencer
# Out:
# The node with the highest number of connections has 402 connections, i.e. the user with most followers and follows

# %% [markdown]
# **In Degree**: it shows the total number of followers from within network

# %%
g_data.vs['in_degree'] = g_data.indegree(mode = 'all')

# %%
print(f"The node with the highest number of incoming connections has {max(g_data.vs['in_degree'])} i.e. our most popular user has this number of follows from within the network")
# Out:
# The node with the highest number of incoming connections has 68 i.e. our most popular user has this number of follows from within the network

# %% [markdown]
# The num_followers column shows some users have more actual followers than the user with the highest in_degree. The in_degree metric actually refers to how many users from within the network follow this user.

# %%
node_df.sort_values(by=["in_degree"], ascending=False).head(5)
# Out:
#        name  num_posts  num_followers  num_following  engagement_grade  \
# 3504   4025        848           1500           5900            0.0108
# 3057   4077        938           2800           3500            0.0525
# 189    6259       4800          23200           5900            0.0104
# 17    13978      14400          33200           7300            0.0115
# 3393    795        867           1900           7300            0.0255
#
#       engagement_rate  followers_growth  outsiders                 Label  \
# 3504         0.348148          8.823530    76.6667    OtherCounseling714
# 3057         0.944444          4.812830    16.2791      MotherlySnack227
# 189          0.112787         -0.075739    33.3333        PrudentPost315
# 17           0.106760         -0.415225    25.0000  DirectPreparation334
# 3393         0.818713          1.035200    89.2857          AchHockey163
#
#         betweenness  ...  in_degree  out_degree  total_degree  \
# 3504   15750.564319  ...         68           3            71
# 3057  121822.497604  ...         67          25            92
# 189   182261.538538  ...         65          64           129
# 17    166420.734561  ...         56          97           153
# 3393   30662.121214  ...         56           7            63
#
#       in_degree_ratio  out_degree_ratio  strength_weighted_in  \
# 3504         0.957746          0.042254              0.183707
# 3057         0.728261          0.271739              0.057445
# 189          0.503876          0.496124              0.093834
# 17           0.366013          0.633987              0.077575
# 3393         0.888889          0.111111              0.017910
#
#       strength_weighted_out  strength_weighted_difference  \
# 3504               0.001184                      0.182523
# 3057               0.082785                     -0.025340
# 189                0.036938                      0.056896
# 17                 0.091132                     -0.013557
# 3393               0.004452                      0.013458
#
#       avg_strength_weighted_in  avg_strength_weighted_out
# 3504                  0.002702                   0.000395
# 3057                  0.000857                   0.003311
# 189                   0.001444                   0.000577
# 17                    0.001385                   0.000940
# 3393                  0.000320                   0.000636
#
# [5 rows x 26 columns]

# %% [markdown]
# The following are the users who are not being followed by anyone in our network.

# %%
node_df[node_df['in_degree']==0][['Label', 'in_degree']]
# Out:
#                          Label  in_degree
# 12             VibrantCanon494          0
# 24              BogusReview160          0
# 74             ClumsySaloon358          0
# 75    Well-GroomedNightmare391          0
# 80            TrivialMemory322          0
# ...                        ...        ...
# 3471      OrderlyExperience119          0
# 3483            LopsidedAss732          0
# 3508        AcrobaticMargin143          0
# 3509         HoarseLoophole757          0
# 3512           StupidFigure433          0
#
# [374 rows x 2 columns]

# %% [markdown]
# **Out-Degree**: it shows the total number of follows

# %%
g_data.vs['out_degree'] = g_data.outdegree(mode = 'all')

# %%
print(f"The node with the highest number of outgoing connections follows {max(g_data.vs['out_degree'])} users, i.e. the most gregarious node")
# Out:
# The node with the highest number of outgoing connections follows 398 users, i.e. the most gregarious node

# %% [markdown]
# The num_following column shows some users follow more users than the user with the highest out_degree. The out_degree metric actually refers to how many users from within the network this user follows.

# %%
node_df.sort_values(by=["out_degree"], ascending=False).head(5)
# Out:
#        name  num_posts  num_followers  num_following  engagement_grade  \
# 1956  56340       1300         584600            408            0.4001
# 1295  50222       1700         753900           1200            0.5134
# 789    5095       2300          17400            412            0.1619
# 2     20432      27400         238200           7000            0.0036
# 15    30650      14700         269800            479            0.1301
#
#       engagement_rate  followers_growth  outsiders                 Label  \
# 1956         2.760760           2.69741    77.7778  WonderfulPancreas742
# 1295         3.542570           2.05649    93.3110        SlimFormula718
# 789          1.748080           2.52448    20.9251      PiercingLayer155
# 2            0.025609          10.00000    16.1804         MilkyThong936
# 15           1.131950           1.79439    85.0004     LegitimatePlug678
#
#         betweenness  ...  in_degree  out_degree  total_degree  \
# 1956   49464.387356  ...          4         398           402
# 1295   26415.024170  ...          6         359           365
# 789   355952.279337  ...         38         350           388
# 2     277292.704916  ...         31         340           371
# 15     35787.715761  ...          7         322           329
#
#       in_degree_ratio  out_degree_ratio  strength_weighted_in  \
# 1956         0.009950          0.990050              0.273011
# 1295         0.016438          0.983562              0.171727
# 789          0.097938          0.902062              0.075892
# 2            0.083558          0.916442              0.226485
# 15           0.021277          0.978723              0.196539
#
#       strength_weighted_out  strength_weighted_difference  \
# 1956              11.874100                    -11.601089
# 1295              11.607234                    -11.435507
# 789                5.482271                     -5.406378
# 2                  0.107252                      0.119233
# 15                 2.795501                     -2.598962
#
#       avg_strength_weighted_in  avg_strength_weighted_out
# 1956                  0.068253                   0.029834
# 1295                  0.028621                   0.032332
# 789                   0.001997                   0.015664
# 2                     0.007306                   0.000315
# 15                    0.028077                   0.008682
#
# [5 rows x 26 columns]

# %% [markdown]
# **Distribution of the followers by degree, out-degree and in-degree**

# %%
sns.histplot([g_data.degree(mode='all'),g_data.indegree(mode = 'all'),g_data.outdegree(mode = 'all')], bins = 30)

# %%
sns.histplot(g_data.vs['degree'], bins = 30)

# %%
sns.histplot(g_data.vs['out_degree'], bins = 30)

# %%
sns.histplot(g_data.vs['in_degree'])

# %% [markdown]
# #### Closeness Centrality
# Refers to how close a user is to the rest of the graph. In this case, this centrality measure doesn't give us the most important user (however, it is used in transportation networks as you are not interested in a node that is connected to other places but tht I am able to go really fast even if I am not highly connected) based on the distance to the rest of the nodes.  It expresses how near a node is to the others by measuring the length of the shortest pathways connecting the vertices.

# %%
 print(f'{max(nx.closeness_centrality(G))} is the user nearest others')
# Out:
# WryCeramic690 is the user nearest others

# %% [markdown]
# #### Eigenvector Centrality
#
# Eigenvector centrality considers the relevance of the surrounding nodes and computes the centrality of a vertex based on the centrality of its neighbors. In technical terms, the metric is proportional to the total of connection centralities.

# %%
max(nx.eigenvector_centrality(G))
# Out:
# 'WryCeramic690'

# %% [markdown]
# #### Betweenness Centrality

# %% [markdown]
# This refers to the user that has the most importance because of the connections it has, its the node that has more connections to the network. This is the node that has the highest number of shared paths within the network.

# %%
max(nx.betweenness_centrality(G))
# Out:
# 'WryCeramic690'

# %% [markdown]
# On our non-weighted graph, the values change showing that user 'JovialSpeaker297' has the highest betweenness centrality measures

# %%
pd.set_option('display.max_columns', 500)
node_df.sort_values(by=["betweenness"], ascending=False).head(5)
# Out:
#        name  num_posts  num_followers  num_following  engagement_grade  \
# 23     5124      12400          11400            337            0.1034
# 789    5095       2300          17400            412            0.1619
# 346   12007       3500          22500           6800            0.0671
# 2103  19188       1200         292900           2900            0.0560
# 2     20432      27400         238200           7000            0.0036
#
#       engagement_rate  followers_growth  outsiders               Label  \
# 23           1.116470          1.677100    11.1345    JovialSpeaker297
# 789          1.748080          2.524480    20.9251    PiercingLayer155
# 346          0.724691          0.078321    39.5062  SuspiciousFilly631
# 2103         0.487083          1.371740    22.6410  GorgeousEcology542
# 2            0.025609         10.000000    16.1804       MilkyThong936
#
#         betweenness  closeness  page_rank_weighted  page_rank  transitivity  \
# 23    423279.058596   0.409482            0.000147   0.000660      0.038078
# 789   355952.279337   0.433021            0.000125   0.000341      0.020410
# 346   334167.872499   0.399482            0.000353   0.000759      0.074908
# 2103  313926.565849   0.428950            0.000282   0.000294      0.038037
# 2     277292.704916   0.440860            0.000443   0.000411      0.024478
#
#       reciprocity  is_loop  in_degree  out_degree  total_degree  \
# 23           True    False         44         258           302
# 789          True    False         38         350           388
# 346         False    False         41          90           131
# 2103        False    False         29         220           249
# 2           False    False         31         340           371
#
#       in_degree_ratio  out_degree_ratio  strength_weighted_in  \
# 23           0.145695          0.854305              0.044973
# 789          0.097938          0.902062              0.075892
# 346          0.312977          0.687023              0.079906
# 2103         0.116466          0.883534              0.182560
# 2            0.083558          0.916442              0.226485
#
#       strength_weighted_out  strength_weighted_difference  \
# 23                 2.941981                     -2.897008
# 789                5.482271                     -5.406378
# 346                0.380115                     -0.300210
# 2103               0.909574                     -0.727014
# 2                  0.107252                      0.119233
#
#       avg_strength_weighted_in  avg_strength_weighted_out
# 23                    0.001022                   0.011403
# 789                   0.001997                   0.015664
# 346                   0.001949                   0.004224
# 2103                  0.006295                   0.004134
# 2                     0.007306                   0.000315

# %%
size = list(nx.degree_centrality(G).values())
size = [x * 1000 for x in size]
labels_filtered = {k: v for k, v in 
    nx.degree_centrality(G).items() if v > 0.5 }
labels = {} 
for k, v in labels_filtered.items(): 
    labels[k] = k

nx.draw_networkx(G, node_size= size, 
                 labels=labels)

pos=nx.shell_layout(G)
x_values, y_values = zip(*pos.values())
x_max = max(x_values)
x_min = min(x_values)
x_margin = (x_max - x_min) * 0.40
plt.xlim(x_min - x_margin, x_max + x_margin)
plt.box(False)
plt.show()

# %% [markdown]
# ### Diameter
# Shortest path between the two furthest nodes

# %%
g_data.diameter()
print(g_data.diameter())
# Out:
# 14

# %% [markdown]
# ### Average path length
# When evaluating pathways and reachability, you may be curious about the distances in your graph. What is the average path length of a social network, or, in other words, what is the average of the shortest distance between each pair of vertices in the graph?

# %%
print(g_data.average_path_length())
# Out:
# 4.658973121766975

# %% [markdown]
# ### Density
# One of the most used measurements is graph density, which accounts for the fraction of edges compared to all potential linkages in the network. Simply said, the density tells us from 0 to 1 how linked the nodes of a graph are.

# %%
 print(nx.density(G))
# Out:
# 0.0027937833883170185

# %% [markdown]
# ### Transitivity
# Linking behaviour determines how links (edges) are formed in social graph. Transitivity is when a friend of my friend is my friend. Normally social networks are really transitive. It is measured by counting the number of triangles x 3 over number of connected triplets.

# %%
GU = nx.from_pandas_edgelist(edges_users_df, source='source_u', target='target_u', edge_attr='Weight')

# %%
print(f'There is a {round(nx.transitivity(G),4)*100} % probability that two users are friends when they have a common contact')
# Out:
# There is a 8.7 % probability that two users are friends when they have a common contact

# %%
node_df.sort_values(by=["transitivity"], ascending=False).head(5)
# Out:
#        name  num_posts  num_followers  num_following  engagement_grade  \
# 220   42211       4400            988            990            0.0109
# 392   49092       3300            354            336            0.1082
# 1897  32281       1300          45200           2200            0.0634
# 2884  62325        981           3000           1400            1.0000
# 3005  42139        950            662            597            0.0554
#
#       engagement_rate  followers_growth  outsiders                      Label  \
# 220          0.348628         10.000000    20.0000              WebbedSkin677
# 392          3.472920         -0.385455    27.1186  Ill-InformedPriesthood422
# 1897         0.589971          1.729880    31.4031         PointlessMinion137
# 2884        19.390700          4.573170    42.4918      MatureIncompetence988
# 3005         1.779120          0.385802    14.0625            ActiveBucket599
#
#       betweenness  closeness  page_rank_weighted  page_rank  transitivity  \
# 220      0.000000   0.311083            0.000426   0.000094           1.0
# 392      0.000000   0.291408            0.000083   0.000070           1.0
# 1897     0.000000   0.249346            0.000138   0.000076           1.0
# 2884   140.545023   0.232386            0.000324   0.000162           1.0
# 3005   367.802947   0.314863            0.000075   0.000063           1.0
#
#       reciprocity  is_loop  in_degree  out_degree  total_degree  \
# 220          True    False          2           0             2
# 392         False    False          2           0             2
# 1897        False    False          2           0             2
# 2884        False    False          2           2             4
# 3005        False    False          2           1             3
#
#       in_degree_ratio  out_degree_ratio  strength_weighted_in  \
# 220          1.000000          0.000000              0.036708
# 392          1.000000          0.000000              0.246895
# 1897         1.000000          0.000000              0.722407
# 2884         0.500000          0.500000              0.163439
# 3005         0.666667          0.333333              0.015542
#
#       strength_weighted_out  strength_weighted_difference  \
# 220                0.000000                      0.036708
# 392                0.000000                      0.246895
# 1897               0.000000                      0.722407
# 2884               0.104193                      0.059247
# 3005               0.009328                      0.006214
#
#       avg_strength_weighted_in  avg_strength_weighted_out
# 220                   0.018354                        NaN
# 392                   0.123448                        NaN
# 1897                  0.361204                        NaN
# 2884                  0.081720                   0.052096
# 3005                  0.007771                   0.009328

# %% [markdown]
# ### Reciprocity
# When I follow you, you follow me back. The more it happens in the graph, the more  reciprocity it has.

# %%
print(f'{round(nx.reciprocity(G),4)*100}% of users follow and are followed back in our network')
# Out:
# 19.45% of users follow and are followed back in our network

# %%
node_df['reciprocity'].value_counts()
# Out:
# False    2683
# True      837
# Name: reciprocity, dtype: int64

# %% [markdown]
# ### Visual Analysis

# %%
vertices_reduced.rename(columns={"Id": "id", 'Label': 'username'}, inplace = True)
edges_df.rename(columns={"Source": "id", 'Target': 'target'}, inplace = True)

# %%
edges_users_df = pd.merge(
    vertices_df[['id', 'username']], edges_df, how="left", on=["id"]
 )
edges_users_df = pd.merge(
    vertices_df[['id', 'username']], edges_users_df, how="left", left_on=["id"], right_on=['target']
 )
del edges_users_df['target']
edges_users_df.rename(columns={"id_x": "id_source",
                               "id_y": "id_target",
                               'target': 'Target',
                               'username_x': 'source_u',
                               'username_y': 'target_u' }, inplace = True)
edges_users_df.dropna(inplace=True)
edges_users_df['id_target'] = edges_users_df['id_target'].astype(int)

# %%
import numpy as np
# get density of network:
print("Density: %s" % nx.density(G))

# plot in_and out degree distribution
in_degree_sequence = sorted([d for n, d in G.in_degree()], reverse=True)  # in_degree sequence
in_degreeCount = collections.Counter(in_degree_sequence)
in_deg, in_cnt = zip(*in_degreeCount.items())
print("Average In Degree %s" % (sum(in_degree_sequence) / len(in_degree_sequence)))

out_degree_sequence = sorted([d for n, d in G.out_degree()], reverse=True)  # out_degree sequence
out_degreeCount = collections.Counter(out_degree_sequence)
out_deg, out_cnt = zip(*out_degreeCount.items())
print("Average Out Degree %s" % (sum(out_degree_sequence) / len(out_degree_sequence)))



plt.figure(figsize = (7,5))
max_degree = max(max(out_degree_sequence), max(in_degree_sequence))
bins = 50
plt.hist(in_degree_sequence, bins, alpha=0.8, label='In degree', color="g")
plt.hist(out_degree_sequence, bins, alpha=0.8, label='Out degree', color="r")
plt.title("Degree distibution",size = 12)
plt.xlabel("Degree",size = 10)
plt.ylabel("Counts",size= 10)
plt.xticks(np.arange(0, max_degree + 1, step=50), rotation=90)
plt.legend(loc='upper right')
#plt.show()
plt.savefig("degree_distribution.png", dpi=300)

# get average shortest path length
path_lengths = []
for v in G.nodes():
    spl = dict(nx.single_source_shortest_path_length(G, v))
    for p in spl:
        path_lengths.append(spl[p])

print("Average Shortest Path Length %s" % (sum(path_lengths) / len(path_lengths)))
# Out:
# Density: 0.0027937833883170185
# Average In Degree 9.11611519607843
# Average Out Degree 9.11611519607843
# Average Shortest Path Length 4.657110613959689

# %% [markdown]
# ### Accounts not followed by anyone

# %%
accounts_with_zero_following=[]
for id,val in (G.out_degree):
    if val==0:
        accounts_with_zero_following.append((id, G.in_degree(id)))
        
accounts_with_0_following_sorted = sorted(accounts_with_zero_following, key=lambda x:x[1], reverse=True)

# %% [markdown]
# The following DataFrame contains all users that are not followed by anyone on the network

# %%
pd.DataFrame(accounts_with_0_following_sorted, columns=['Account','Following count']).head(5)
# Out:
#               Account  Following count
# 0       FastCyclone65               96
# 1    Well-LitHuman480               78
# 2        NoisyMaid872               49
# 3  MeaslyAlpenhorn928               48
# 4  QuixoticAzimuth278               35

# %% [markdown]
# ### Accounts not following anyone

# %%
accounts_with_zero_followers=[]
for id,val in (G.in_degree):
    if val==0:
        accounts_with_zero_followers.append((id,G.out_degree(id)))
        
accounts_with_0_followers_sorted = sorted(accounts_with_zero_followers, key=lambda x:x[1], reverse=True)

# %% [markdown]
# The following DataFrame contains all users that are not following anyone on the network

# %%
pd.DataFrame(accounts_with_0_followers_sorted, columns=['Account','Follower count']).head(5)
# Out:
#                Account  Follower count
# 0         WiseHurdle80              29
# 1  ScholarlyHabitat300              29
# 2  CultivatedTshirt365              29
# 3   TornElimination216              28
# 4        FrizzyBabe198              25

# %% [markdown]
# ###  PageRank
# Most important Node According to the algorithm.

# %%
ppr1 = nx.pagerank(G, alpha=0.85, personalization=None, max_iter=100, tol=1e-06, nstart=None, weight='weight', dangling=None)

# %%
max(ppr1.items(), key = lambda k : k[1])
# Out:
# ('JovialSpeaker297', 0.011770581691008654)

# %%
print(f"The most important person according to PageRank is {max(ppr1.items(), key = lambda k : k[1])[0]}")
# Out:
# The most important person according to PageRank is JovialSpeaker297

# %% [markdown]
# Below are the top 5 most important persons according to PageRank.

# %%
import heapq
heapq.nlargest(5, ppr1, key=ppr1.get)
# Out:
# ['JovialSpeaker297',
#  'PiercingLayer155',
#  'SlimFormula718',
#  'WonderfulPancreas742',
#  'PowerfulFuton102']

# %%
print("Neighbors of JovialSpeaker297", [n for n in G.neighbors("JovialSpeaker297")])
# Out:
# Neighbors of JovialSpeaker297 ['NaturalMultimedia960', 'OverduePitching571', 'Black-And-WhiteCephalopod883', 'CloseCitizenship193', 'MotherlySnack227', 'OilyStiletto374', 'JovialSunbonnet174', 'Black-And-WhiteBead198', 'GloriousSuccess341', 'GlumClick952', 'PiercingLayer155', 'FantasticElver367', 'VisibleVariable969', 'AverageDickey915', 'BareRag130', 'MatureMotherinlaw757', 'GlossyMime471', 'VastDrawing511', 'VisibleEyelids581', 'Well-To-DoFly714', 'FluffyFaithful726', 'CrookedWashbasin369', 'OblongHeel181', 'FreeEstuary855', 'StarchyBrass268', 'CommonBlessing274', 'UnsightlyTrench336', 'PertinentClipper121', 'UnfinishedCensus220', 'AccurateBicycle98', 'ObedientTeenager190', 'AdventurousVenom477', 'FatalPenis829', 'GrownPantology81', 'AgedIllness365', 'FatalFlume328', 'ThunderousComparison364', 'OutstandingTesting635', 'BriefPuggle783', 'WidePattypan609', 'CleanTrunk182', 'RipeBlog221', 'SerpentineLeisure819', 'LooseLink106']

# %%
node_df.sort_values(by=["page_rank_weighted"], ascending=False).head(5)
# Out:
#        name  num_posts  num_followers  num_following  engagement_grade  \
# 3077  18586        935           3500           6600            0.0348
# 1500  12918       1600           1500           6200            0.0406
# 1909  11159       1300           3200           7500            0.0428
# 1859  18537       1368           2200           6488            0.0062
# 801   42653       2200           1400           3800            0.0070
#
#       engagement_rate  followers_growth  outsiders                   Label  \
# 3077         0.626984          0.551471    33.7838       PlaintiveBlade198
# 1500         1.303700          1.115400    64.1667        FlusteredRite388
# 1909         0.770833         10.000000    67.0000  Quick-WittedVanilla237
# 1859         0.111111          0.855400    54.5455        RoundHygienic601
# 801          0.226190          7.100590    10.0000       GloriousQuinoa940
#
#        betweenness  closeness  page_rank_weighted  page_rank  transitivity  \
# 3077  28379.938717   0.342679            0.002391   0.002378      0.057895
# 1500   5052.116134   0.386147            0.002265   0.001766      0.113415
# 1909  16599.848508   0.342824            0.002264   0.001287      0.180952
# 1859  26062.436525   0.347756            0.002209   0.004003      0.064103
# 801    2646.207291   0.329736            0.002072   0.000419      0.166667
#
#       reciprocity  is_loop  in_degree  out_degree  total_degree  \
# 3077        False    False         17          12            29
# 1500        False    False         40           2            42
# 1909        False    False         14           5            19
# 1859         True    False         52           5            57
# 801         False    False          9           1            10
#
#       in_degree_ratio  out_degree_ratio  strength_weighted_in  \
# 3077         0.586207          0.413793              0.038274
# 1500         0.952381          0.047619              0.083955
# 1909         0.736842          0.263158              0.183161
# 1859         0.912281          0.087719              0.006483
# 801          0.900000          0.100000              0.233352
#
#       strength_weighted_out  strength_weighted_difference  \
# 3077               0.035485                      0.002789
# 1500               0.006812                      0.077142
# 1909               0.010252                      0.172909
# 1859               0.001872                      0.004610
# 801                0.010401                      0.222951
#
#       avg_strength_weighted_in  avg_strength_weighted_out
# 3077                  0.002251                   0.002957
# 1500                  0.002099                   0.003406
# 1909                  0.013083                   0.002050
# 1859                  0.000125                   0.000374
# 801                   0.025928                   0.010401

# %% [markdown]
# ## Community Detection
#
# We will consider our directed network as indirected in order to apply community detection algorithims like Louvrain which are only use for undirected but people commonly treat their directed graph as undirected when applying it.

# %%
! pip install community
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: community in /usr/local/lib/python3.7/dist-packages (1.0.0b1)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (from community) (1.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from community) (2.23.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask->community) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask->community) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask->community) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask->community) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask->community) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->community) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->community) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->community) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->community) (1.24.3)

# %%
import urllib.request
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
import networkx.algorithms.community as nxcom
import community
import community.community_louvain as community_louvain

# %%
GU = nx.from_pandas_edgelist(edges_users_df, source='source_u', target='target_u', edge_attr='Weight')

# %% [markdown]
# The first step in the analysis of subgroups within a network is to find all the available complete subgraphs in an undirected graph. These independant graphs are called `cliques` because every node is connected to every other node.

# %%
print("Number of cliques: ",nx.graph_number_of_cliques(GU))
print("Cliques: ", list(nx.find_cliques(GU)))
# Out:
# Number of cliques:  22524
# Cliques:  [['CloseToaster256', 'DistortedCanoe223'], ['CloseToaster256', 'ImpishDynamics175', 'DelayedHat250'], ['CloseToaster256', 'PowerfulFuton102'], ['CloseToaster256', 'TidyHeadrest648', 'DelayedHat250'], ['CloseToaster256', 'IlliterateCleft662', 'OverduePitching571', 'RubberyMaster868'], ['CloseToaster256', 'MonumentalCampaigning610'], ['TrueNibble210', 'IntentTurnip20'], ['TrueNibble210', 'PlasticPorpoise724'], ['TrueNibble210', 'PlaintiveBlade198', 'Extra-LargeSundae597'], ['TrueNibble210', 'VisibleVariable969'], ['TrueNibble210', 'UncommonPantsuit364'], ['TrueNibble210', 'KindBank787'], ['TrueNibble210', 'FrayedBaritone327', 'FlatMule682'], ['TrueNibble210', 'FrayedBaritone327', 'ForsakenFrenzy548'], ['TrueNibble210', 'NearPrimate757'], ['TrueNibble210', 'LoudDrainage901', 'AffectionateBalcony873'], ['TrueNibble210', 'LoudDrainage901', 'IntrepidLeverage157'], ['TrueNibble210', 'BlushingKilt898', 'GraciousTomorrow388'], ['TrueNibble210', 'BlushingKilt898', 'VoluminousDisarmament460'], ['TrueNibble210', 'CarefreeEstuary888'], ['TrueNibble210', 'SoftGherkin618', 'ComposedHonesty599'], ['TrueNibble210', 'AttentivePaddock685', 'PlumpQuartz403'], ['TrueNibble210', 'CoarseGuilder886', 'ThriftyWestern939'], ['TrueNibble210', 'DifferentShed829'], ['TrueNibble210', 'RoughMineshaft111', 'Big-HeartedTemperature480'], ['TrueNibble210', 'InnocentAglet148'], ['TrueNibble210', 'HorribleHighlight354'], ['TrueNibble210', 'ForsakenFrenzy548', 'HurtfulWindshield180'], ['TrueNibble210', 'GraciousTomorrow388', 'ComposedHonesty599'], ['TrueNibble210', 'PersonalComestible47'], ['TrueNibble210', 'KeyCampaigning5'], ['TrueNibble210', 'TemptingSuitcase874'], ['TrueNibble210', 'FlawedSeaplane556'], ['TrueNibble210', 'NoisyBaseline342'], ['TrueNibble210', 'DeafeningPicturesque627'], ['TrueNibble210', 'TightKazoo520', 'PlumpQuartz403', 'FlatMule682'], ['TrueNibble210', 'TightKazoo520', 'PlumpQuartz403', 'HurtfulWindshield180'], ['TrueNibble210', 'TightKazoo520', 'PlumpQuartz403', 'HoarseGreenhouse958'], ['TrueNibble210', 'TightKazoo520', 'ColossalHydroxyl353', 'Big-HeartedTemperature480'], ['TrueNibble210', 'TightKazoo520', 'FumblingForum409'], ['TrueNibble210', 'Far-FlungGrace567'], ['TrueNibble210', 'SelfishHardship31'], ['TrueNibble210', 'DrearyDigger336', 'ComposedHonesty599'], ['TrueNibble210', 'VoluminousDisarmament460', 'Big-HeartedTemperature480'], ['TrueNibble210', 'GivingPatriot619'], ['TrueNibble210', 'UniformSin224'], ['TrueNibble210', 'FrailPolliwog372', 'PlumpQuartz403'], ['TrueNibble210', 'ImpassionedScrew101'], ['TrueNibble210', 'ComposedHonesty599', 'StripedCounselor853'], ['TrueNibble210', 'ValuableUnderestimate189'], ['TrueNibble210', 'FluffyBlackfish128'], ['TrueNibble210', 'GrowingAtelier796', 'ColossalHydroxyl353'], ['TrueNibble210', 'DependentPunctuation324'], ['TrueNibble210', 'DimBirdcage601'], ['TrueNibble210', 'StupidBusinessman717'], ['BriskGreatgrandmother916', 'MulticoloredWalker972'], ['VisibleVariable969', 'FittingCounterforce932', 'AlarmedGoing126'], ['VisibleVariable969', 'OvercookedConcept126', 'LegitimatePlug678'], ['VisibleVariable969', 'OvercookedConcept126', 'DirtyMastication438'], ['VisibleVariable969', 'WoodenIntervenor190'], ['VisibleVariable969', 'AchingPoker524', 'PurpleJellyfish977', 'AlarmedGoing126'], ['VisibleVariable969', 'AchingPoker524', 'PurpleJellyfish977', 'Extra-LargeDandelion123'], ['VisibleVariable969', 'JollyMachine469', 'PiercingLayer155'], ['VisibleVariable969', 'JollyMachine469', 'Extra-LargeDandelion123'], ['VisibleVariable969', 'JollyMachine469', 'LegitimatePlug678'], ['VisibleVariable969', 'AlarmedGoing126', 'PurpleJellyfish977', 'SilkyAtheist246'], ['VisibleVariable969', 'AlarmedGoing126', 'PurpleJellyfish977', 'SquigglyChime827'], ['VisibleVariable969', 'AlarmedGoing126', 'PurpleJellyfish977', 'MoistLegume333'], ['VisibleVariable969', 'AlarmedGoing126', 'SweetCohort194'], ['VisibleVariable969', 'SilkyAtheist246', 'Extra-LargeDandelion123', 'PurpleJellyfish977'], ['VisibleVariable969 ...

# %%
cluster1 = nxcom.girvan_newman(GU)

# %%
c1 = next(cluster1)
print(f"Girvan-Neuman:\nLength {len(c1)}")
print(f"Modularity: "
      f"{nxcom.modularity(GU, c1):.2f}")
print(f"Membership: {c1}")
# Out:
# Girvan-Neuman:
# Length 12
# Modularity: 0.00
# Membership: ({'CloseToaster256', 'TrueNibble210', 'BriskGreatgrandmother916', 'VisibleVariable969', 'FirmRelief485', 'RadiantPannier715', 'UpsetExcess791', 'LiquidPrefix686', 'AridNudge149', 'CornyOpossum497', 'RoundVitro86', 'InferiorSentencing752', 'IncompleteManufacturing357', 'HumongousPile707', 'CrushingSelfconfidence479', 'BasicCoincidence568', 'EmbellishedCleavage255', 'CruelBeanie958', 'LegalChairperson269', 'TriflingHandball404', 'BeautifulTrapdoor804', 'ReliableTrigonometry332', 'KnowingDerrick78', 'AnyCost486', 'FlippantSpreadsheet647', 'PettyBuckle689', 'CommonPurple65', 'ClutteredPeninsula335', 'CoarseUnderstanding235', 'FavorableBucket326', 'OrderlyDisplay44', 'BusyGlee241', 'VioletMisogyny399', 'SlimFormula718', 'FabulousWoodchuck308', 'ClutteredDecadence390', 'LameImitation17', 'NaughtyDot116', 'AngrySponge126', 'JuniorCashier969', 'AccomplishedMincemeat776', 'FussyPredecessor14', 'TeemingSkeleton456', 'PowerfulRunway159', 'IncomparableCuticle986', 'DefiantVolume417', 'OldFruit455', 'UpbeatWok8', 'QuintessentialNod490', 'SnoopyParsnip370', 'RubberyFallingout131', 'FittingGoodie736', 'SlightLegacy10', 'GenuineHurdle638', 'RemorsefulFilth624', 'LividTrunk818', 'WorthwhileInversion124', 'ScrawnyHealthcare690', 'GiganticSpecialist894', 'RepulsiveGong867', 'ImpeccableFeature586', 'UnimportantHike542', 'MonthlyDickey654', 'OffensiveAudit268', 'JubilantCloves608', 'ThriftyBoutique207', 'SubmissivePostfix182', 'CourageousHomosexual379', 'SpiritedGift139', 'CharmingMasonry33', 'GreenPoem262', 'NeglectedGinseng4', 'ThoseInventory80', 'MarriedInfant496', 'UnawareCountry904', 'HomelyNeon722', 'DangerousPitching695', 'ForsakenCradle892', 'WorriedMiter265', 'CornyLode653', 'NaturalMultimedia960', 'TameSeal599', 'AmazingAnswer383', 'IlliterateSelfesteem557', 'IllRostrum648', 'FullSpecies121', 'EmbarrassedZoo649', 'DullSlavery902', 'MeekChastity697', 'ElasticSpool226', 'JauntyGinger808', 'CylindricalDare611', 'Happy-Go-LuckyPromenade236', 'SphericalTrick724', 'SuperficialAcrylic569', 'SingleAssurance672', 'WideGreens934', 'ShadyDiet623', 'PlumpTape643', 'IlliterateEarplug485', 'OtherPlumber752', 'Black-And-WhiteProprietor662', 'MindlessPheasant596', 'MoistAppendix759', 'ThisShirt674', 'ShamelessContinent609', 'HelplessFloodplain666', 'HarshBall631', 'WhisperedGym779', 'ActiveBloomer825', 'PlayfulTimber654', 'EthicalEngineering618', 'DeterminedCore707', 'LeftVaccine638', 'MotherlyLoop234', 'ImpolitePiece930', 'HeartyFriend162', 'UpbeatAlert982', 'ScentedRise342', 'MotherlySnack227', 'ProbableHemisphere844', 'FastCyclone65', 'WholeBlizzard409', 'MisguidedDigger849', 'JollyCamp502', 'FabulousOrnament428', 'MeekViscose607', 'TatteredBeet143', 'HarshInscription628', 'RemorsefulBiplane909', 'DisastrousChops297', 'TraumaticChopsticks461', 'DisastrousStepmother601', 'FuzzyOrganising960', 'ImmenseField614', 'DamagedCrucifixion222', 'GracefulBrowser583', 'ColorfulRawhide67', 'LinearSubtitle106', 'CompleteNumismatist61', 'AdventurousVenom477', 'WiseLust210', 'KnobbyLipstick572', 'RipeBracket242', 'PartialAcre748', 'DamagedPimple910', 'PleasedHelmet597', 'Happy-Go-LuckyGrowth795', 'FatalPenis829', 'SlipperyGirdle107', 'CylindricalTrench598', 'HauntingPretzel305', 'StrikingBanker504', 'ThoughtfulSlide26', 'ImportantSnowstorm620', 'GlitteringTransom270', 'EthicalFulfillment300', 'UnconsciousTankful464', 'VivaciousProvidence886', 'SuperiorDory763', 'RecklessDoorbell28', 'Self-ReliantAppliance554', 'ProductiveInsectarium267', 'NumbResult391', 'MedicalOrganizing211', 'TrustyFilter144', 'UnlinedExercise212', 'ClumsyDollar592', 'PepperySpace498', 'UncomfortableDory952', 'UnhappyRepair460', 'RecentNectar334', 'PoisedBarbeque59', 'LostTambourine736', 'EducatedProfessor408', 'VibrantClaim866', 'LumpyConfidence969', 'IrresponsibleDetour360', 'WrongEmployer556', 'ProfuseManacle946', 'PlasticWealth881', 'PeriodicTourism630', 'CloudyCloudburst322', 'TediousShoot273', 'CheeryHappening433', 'Well-DocumentedBuilder854', 'SleepyChipmunk961', 'Well-To-DoFly ...

# %%
print("Louvain")
cluster2 = community_louvain.best_partition(GU)
print("Length: "
      f"{float(len(set(cluster2.values())))}")
print("Modularity: "
      f"{community_louvain.modularity(cluster2, GU):.2f}")
print(f"Membership: {cluster2}")

print("\nGreedy optimization")
cluster3 = nxcom.greedy_modularity_communities(GU)
c3 = sorted(cluster3, key=len, reverse=True)
print(f"Length {len(c3)}")
print("Modularity:"
      f"{nxcom.modularity(GU, c3):.2f}")
print(f"Membership: {c3}")

print("\nPropagating label: ")
cluster4 = nxcom.asyn_lpa_communities(GU)
c4 = sorted(cluster4, key=len, reverse=True)
print("Length: ", len(c4))
print("Modularity:"
      f"{nxcom.modularity(GU, c4):.2f}")
print("Membership: ", c4)
# Out:
# Louvain
# Length: 20.0
# Modularity: 0.38
# Membership: {'HonestGazebo218': 0, 'Happy-Go-LuckyPromenade236': 0, 'ThoseTeam570': 1, 'TreasuredBlossom795': 0, 'EmbarrassedAltitude532': 0, 'IncredibleCompletion886': 0, 'StiffBoogeyman321': 2, 'LeanClothing380': 0, 'HeartfeltWorkout965': 0, 'MelodicSorrow248': 2, 'WarmConcept463': 3, 'ElatedWetsuit549': 4, 'AccurateKing137': 2, 'CumbersomeDebate9': 2, 'ComplexEcumenist118': 4, 'GlamorousMetal988': 4, 'NaturalMultimedia960': 1, 'OccasionalTrove526': 1, 'JovialSunbonnet174': 1, 'JovialSpeaker297': 1, 'ShockingHunchback599': 1, 'NearThread698': 1, 'Jam-PackedBifocals45': 2, 'NearPrimate757': 3, 'RashGrowth431': 2, 'GlumFootrest980': 1, 'VastRaisin296': 1, 'Easy-GoingTale57': 0, 'BadCreature542': 0, 'PowerlessLadle852': 0, 'UnfitResemblance213': 2, 'NumbFocus206': 3, 'PointedPulse880': 0, 'DisloyalChicken280': 2, 'Far-OffStorytelling212': 0, 'ProfuseNapkin58': 0, 'ImpressiveAttention644': 0, 'FussyClearance108': 0, 'SmallJelly930': 0, 'VioletMisogyny399': 1, 'ImperfectRecall761': 4, 'UnpleasantBangle245': 2, 'UnfortunateTherapist855': 0, 'RotatingDegree439': 0, 'CheerfulTrace258': 4, 'SlimyCrisis758': 5, 'GiganticConformation178': 1, 'AccomplishedVote579': 1, 'BowedDoubter475': 5, 'HelplessUplift516': 1, 'HiddenFlung584': 1, 'GreenRelation875': 1, 'WarmheartedDecade891': 1, 'TenderHumor475': 1, 'TreasuredHawk565': 4, 'Self-ReliantTruth445': 4, 'FalseMother844': 4, 'PowerfulCarry9': 4, 'PeriodicTourism630': 5, 'High-LevelStove580': 1, 'ColossalGrand245': 5, 'AjarFord741': 1, 'PalatableWedge528': 6, 'SpottedEardrum786': 5, 'Second-HandSense739': 5, 'PowerfulFuton102': 1, 'InfatuatedRotation970': 5, 'LinedBribery601': 1, 'PerfectPolarisation374': 4, 'PleasantBreast679': 1, 'SpeedyEyrie615': 4, 'LameKiss900': 4, 'NiceHalf105': 4, 'ObedientTeenager190': 5, 'AttractiveAgreement773': 6, 'EnragedSeed589': 4, 'RoundHeifer528': 1, 'EsteemedThaw49': 5, 'FatalFlume328': 1, 'LongStatue177': 2, 'HospitableErosion979': 5, 'NoisyMaid872': 5, 'OpenContainer28': 4, 'SaltyFlexibility691': 4, 'TrainedWarmth645': 5, 'OrnateInsurance219': 1, 'LegitimatePlug678': 6, 'BruisedComic534': 4, 'EcstaticBud710': 5, 'ThoughtfulEffort490': 5, 'JollyMachine469': 5, 'GranularPrestige647': 4, 'IntrepidLeverage157': 5, 'CrowdedIntensity305': 4, 'RipeBlog221': 6, 'GivingCheek371': 0, 'AverageSculpture428': 2, 'BelovedProhibition368': 6, 'HatefulCulture585': 5, 'PiercingLayer155': 3, 'PrudentPost315': 2, 'ThoseGliding259': 2, 'CheeryHappening433': 2, 'ThreadbareHate813': 6, 'BelatedBackpack41': 0, 'DirectPreparation334': 2, 'ActiveImbalance947': 1, 'UnripeFacility754': 0, 'FineGrabbag356': 5, 'SpiritedGift139': 4, 'StrikingLiving305': 2, 'ScornfulLeave840': 6, 'PrimaryHurdler443': 2, 'DependentPremier160': 6, 'FortunateConstraint807': 6, 'SereneSundae175': 2, 'SingleAssurance672': 0, 'DeficientYeast355': 0, 'ComplexTrance802': 0, 'RoyalInfection167': 2, 'FamousAgenda991': 6, 'SoftHippopotamus977': 0, 'FineRag558': 5, 'EthicalAggradation283': 6, 'FocusedBakery487': 6, 'MutedPurse75': 2, 'GorgeousEcology542': 2, 'WearyTear603': 6, 'DaringMonster60': 6, 'SlimFormula718': 6, 'Well-GroomedApple227': 0, 'AdoredCucumber609': 0, 'CheerfulBoon948': 5, 'Happy-Go-LuckyBather494': 0, 'SuburbanAbacus852': 5, 'NoisyCare654': 5, 'LuminousDeployment153': 5, 'Well-To-DoChaos367': 5, 'AngrySponge126': 5, 'RashIssue28': 5, 'MealyUnderstanding620': 5, 'SophisticatedOptimal750': 5, 'BleakCabin511': 5, 'SeriousSkullduggery440': 5, 'OutlandishZero181': 5, 'UniformGlut825': 5, 'PunctualCongo727': 4, 'NoxiousVoid530': 5, 'UnhappySeaside812': 6, 'ConcreteOrganization21': 4, 'MeagerArmadillo52': 1, 'FirstParagraph341': 6, 'VoluminousTanktop711': 0, 'BlueWarmup896': 5, 'PortlyBricklaying884': 6, 'PreviousCivilian622': 5, 'CanineDissemination486': 5, 'PoorUplift839': 5, 'IntelligentPrice544': 5, 'GrandTempo216': 5, 'RobustActivation604': 4, 'CluelessRuin327': 6, 'ThoseShutdown610': 3, 'LoathsomeCountry365': 5, 'UnsightlyTrench336': 1, 'FabulousWoodchuck308': 6, 'FlatNurse24': 3, 'TurbulentMech ...
#
# Greedy optimization
# Length 40
# Modularity:0.33
# Membership: [frozenset({'UtterGym694', 'BriskGreatgrandmother916', 'VisibleVariable969', 'RadiantPannier715', 'ViolentLysine882', 'UnrealisticGreatness576', 'UpsetExcess791', 'ParallelInitial915', 'RoundVitro86', 'AntiqueMusicbox293', 'TerrificProgression730', 'CruelBeanie958', 'BasicWaterbed504', 'TriflingHandball404', 'KnowingDerrick78', 'TenderChassis70', 'AnyCost486', 'FlippantSpreadsheet647', 'CoarseUnderstanding235', 'FondShelf674', 'CommonPurple65', 'PettyBuckle689', 'RemoteOxford259', 'FavorableBucket326', 'VioletMisogyny399', 'OffbeatFallacy202', 'HeavenlyMainstream671', 'NaughtyDot116', 'AngrySponge126', 'SleepyToothbrush803', 'JuniorCashier969', 'MellowArray564', 'AccomplishedMincemeat776', 'TeemingSkeleton456', 'LumpyType134', 'PowerfulRunway159', 'IncomparableCuticle986', 'GenuineOlive204', 'SuburbanAbacus852', 'LikableAngle655', 'RubberyFallingout131', 'UglyUnit311', 'BaggyIndication896', 'FittingGoodie736', 'MotherlyStance213', 'KindLoaf651', 'LividTrunk818', 'ProductiveTussle898', 'PassionateBeauty26', 'ScrawnyHealthcare690', 'BlissfulSneeze425', 'UnimportantHike542', 'JubilantCloves608', 'SubmissivePostfix182', 'CourageousHomosexual379', 'GrumpyContingency524', 'SpiritedGift139', 'GreenPoem262', 'ThoseInventory80', 'BowedDoubter475', 'PowerfulCarry9', 'UnawareCountry904', 'AdorableCorn118', 'SteepGlockenspiel231', 'RoundScore863', 'DangerousPitching695', 'VitalHandrail405', 'EnormousQuilt395', 'ConstantDart982', 'RectangularMerchant87', 'CornyLode653', 'AngryTypewriter542', 'SameBreastplate286', 'TameSeal599', 'IlliterateSelfesteem557', 'FullSpecies121', 'IllRostrum648', 'DullSlavery902', 'MeekChastity697', 'CheapDiaper839', 'PlumpTape643', 'AdorableRoom776', 'MindlessPheasant596', 'PrivateSphere472', 'WhisperedGym779', 'BrightOrnament5', 'MotherlyLoop234', 'LeftVaccine638', 'ImpolitePiece930', 'UpbeatAlert982', 'ScentedRise342', 'MotherlySnack227', 'SplendidSilica65', 'Ill-InformedPriesthood422', 'BelovedShield962', 'AwkwardDiffuse658', 'PertinentRomaine970', 'FabulousOrnament428', 'PersonalComestible47', 'AngelicFries577', 'ImmenseField614', 'LinearSubtitle106', 'SuddenPassion332', 'WiseLust210', 'TidyLegging733', 'LeadingJam567', 'PleasedHelmet597', 'RobustPet465', 'SlipperyGirdle107', 'CylindricalTrench598', 'VillainousBlame795', 'StrikingBanker504', 'GranularPrestige647', 'DimwittedOxygen282', 'CostlyMambo157', 'UnlinedFrown193', 'MutedOutlay462', 'PhonyCurio374', 'UnconsciousTankful464', 'SentimentalManager398', 'WaterloggedCircumference915', 'DelayedHat250', 'RecklessDoorbell28', 'ProductiveInsectarium267', 'UnlinedExercise212', 'TrustyFilter144', 'UnhappyRepair460', 'RecentNectar334', 'EducatedProfessor408', 'AngelicAardvark241', 'VibrantClaim866', 'BoldDud917', 'WrongEmployer556', 'LoathsomeCountry365', 'ProfuseManacle946', 'TintedOmelet821', 'PeriodicTourism630', 'CheeryHappening433', 'SleepyChipmunk961', 'DoubleGunpowder462', 'AustereAlgebra215', 'AmazingDuck436', 'StiffArtichoke749', 'PessimisticHalt204', 'WarmheartedChop269', 'ObesePen103', 'GaseousPilgrimage291', 'SafeBeating30', 'WrongPreface399', 'LovableSuck97', 'ConfusedCarabao536', 'HurtfulGood407', 'AchingPoker524', 'LuxuriousEnvironment460', 'Old-FashionedHygienic485', 'LameHash425', 'ImperfectRecall761', 'KeenInn656', 'CheeryLeadership118', 'ThoughtfulEffort490', 'PettyEctodermal839', 'FrizzyTeriyaki203', 'ScarceSubgroup552', 'LovelyInvestor494', 'UniqueContact81', 'UnfoldedAuthority70', 'VeneratedPardon609', 'SlimyCrisis758', 'LinedBloom320', 'ExcitedWish506', 'NeglectedChalet949', 'SnarlingCut226', 'UnwrittenExhibition324', 'ClosedPatent863', 'HurtfulMost816', 'SuperiorPruner32', 'TrustworthyObsidian441', 'SlimyUrn616', 'WorriedEmployee965', 'HumiliatingRailing393', 'DishonestJustice960', 'SecretTrait221', 'OvercookedConcept126', 'GrubbyGallery606', 'StrongHobby971', 'EmotionalGift86', 'WoodenIntervenor190', 'EnchantingCompress972', 'NiceHalf105', 'CourageousGratitude611', 'CarefulNode187', 'MonumentalLunge189', 'VengefulEverybody363',  ...
#
# Propagating label:
# Length:  37
# Modularity:0.01
# Membership:  [{'CloseToaster256', 'TrueNibble210', 'BriskGreatgrandmother916', 'VisibleVariable969', 'FirmRelief485', 'RadiantPannier715', 'UpsetExcess791', 'LiquidPrefix686', 'AridNudge149', 'CornyOpossum497', 'RoundVitro86', 'InferiorSentencing752', 'IncompleteManufacturing357', 'HumongousPile707', 'CrushingSelfconfidence479', 'BasicCoincidence568', 'EmbellishedCleavage255', 'CruelBeanie958', 'LegalChairperson269', 'TriflingHandball404', 'KnowingDerrick78', 'ReliableTrigonometry332', 'BeautifulTrapdoor804', 'AnyCost486', 'FlippantSpreadsheet647', 'CoarseUnderstanding235', 'PettyBuckle689', 'CommonPurple65', 'ClutteredPeninsula335', 'FavorableBucket326', 'OrderlyDisplay44', 'BusyGlee241', 'VioletMisogyny399', 'SlimFormula718', 'FabulousWoodchuck308', 'ClutteredDecadence390', 'LameImitation17', 'NaughtyDot116', 'AngrySponge126', 'JuniorCashier969', 'AccomplishedMincemeat776', 'FussyPredecessor14', 'TeemingSkeleton456', 'PowerfulRunway159', 'IncomparableCuticle986', 'DefiantVolume417', 'OldFruit455', 'UpbeatWok8', 'QuintessentialNod490', 'SnoopyParsnip370', 'RubberyFallingout131', 'FittingGoodie736', 'SlightLegacy10', 'GenuineHurdle638', 'RemorsefulFilth624', 'LividTrunk818', 'WorthwhileInversion124', 'ScrawnyHealthcare690', 'ImpeccableFeature586', 'GiganticSpecialist894', 'RepulsiveGong867', 'UnimportantHike542', 'MonthlyDickey654', 'OffensiveAudit268', 'JubilantCloves608', 'ThriftyBoutique207', 'SubmissivePostfix182', 'CourageousHomosexual379', 'SpiritedGift139', 'GreenPoem262', 'NeglectedGinseng4', 'ThoseInventory80', 'MarriedInfant496', 'UnawareCountry904', 'DangerousPitching695', 'HomelyNeon722', 'ForsakenCradle892', 'WorriedMiter265', 'CornyLode653', 'NaturalMultimedia960', 'TameSeal599', 'IlliterateSelfesteem557', 'AmazingAnswer383', 'FullSpecies121', 'IllRostrum648', 'EmbarrassedZoo649', 'DullSlavery902', 'MeekChastity697', 'ElasticSpool226', 'JauntyGinger808', 'CylindricalDare611', 'Happy-Go-LuckyPromenade236', 'SphericalTrick724', 'SingleAssurance672', 'SuperficialAcrylic569', 'WideGreens934', 'ShadyDiet623', 'PlumpTape643', 'IlliterateEarplug485', 'Black-And-WhiteProprietor662', 'MindlessPheasant596', 'MoistAppendix759', 'ThisShirt674', 'ShamelessContinent609', 'HelplessFloodplain666', 'HarshBall631', 'WhisperedGym779', 'ActiveBloomer825', 'PlayfulTimber654', 'EthicalEngineering618', 'DeterminedCore707', 'LeftVaccine638', 'MotherlyLoop234', 'ImpolitePiece930', 'UpbeatAlert982', 'ScentedRise342', 'MotherlySnack227', 'ProbableHemisphere844', 'FastCyclone65', 'WholeBlizzard409', 'MisguidedDigger849', 'JollyCamp502', 'FabulousOrnament428', 'MeekViscose607', 'TatteredBeet143', 'RemorsefulBiplane909', 'HarshInscription628', 'DisastrousChops297', 'TraumaticChopsticks461', 'DisastrousStepmother601', 'ImmenseField614', 'DamagedCrucifixion222', 'GracefulBrowser583', 'ColorfulRawhide67', 'CompleteNumismatist61', 'LinearSubtitle106', 'AdventurousVenom477', 'WiseLust210', 'KnobbyLipstick572', 'RipeBracket242', 'PartialAcre748', 'DamagedPimple910', 'PleasedHelmet597', 'Happy-Go-LuckyGrowth795', 'FatalPenis829', 'SlipperyGirdle107', 'CylindricalTrench598', 'HauntingPretzel305', 'StrikingBanker504', 'ThoughtfulSlide26', 'ImportantSnowstorm620', 'GlitteringTransom270', 'EthicalFulfillment300', 'UnconsciousTankful464', 'VivaciousProvidence886', 'SuperiorDory763', 'RecklessDoorbell28', 'Self-ReliantAppliance554', 'ProductiveInsectarium267', 'NumbResult391', 'UnlinedExercise212', 'TrustyFilter144', 'ClumsyDollar592', 'MedicalOrganizing211', 'PepperySpace498', 'UncomfortableDory952', 'UnhappyRepair460', 'RecentNectar334', 'PoisedBarbeque59', 'LostTambourine736', 'EducatedProfessor408', 'VibrantClaim866', 'LumpyConfidence969', 'IrresponsibleDetour360', 'WrongEmployer556', 'ProfuseManacle946', 'PlasticWealth881', 'PeriodicTourism630', 'CloudyCloudburst322', 'TediousShoot273', 'CheeryHappening433', 'Well-DocumentedBuilder854', 'SleepyChipmunk961', 'Well-To-DoFly714', 'AustereAlgebra215', 'StiffArtichoke749', 'JuvenileStitch694', 'OffbeatJui ...

# %%
#Plot with Louvain algortihm
pos = nx.spring_layout(GU)
plt.figure(figsize=(12,6))
plt.axis("off")
nx.draw_networkx_labels(GU,pos,font_size=6)
nx.draw_networkx_nodes(GU, pos,
        cmap=plt.cm.RdYlBu,
        node_color=list(cluster2.values()))
nx.draw_networkx_edges(GU, pos, alpha=0.3)
plt.show(GU)

# %% [markdown]
# ## Information Diffusion

# %% [markdown]
# In order to identify if our top user is able to transport information efficiently, we will use a SIR model to compare it against the node with the least centrality measures.

# %% [markdown]
# Hide Warnings

# %%
from IPython.display import HTML
HTML('''<script>
code_show_err=false; 
function code_toggle_err() {
 if (code_show_err){
 $('div.output_stderr').hide();
 } else {
 $('div.output_stderr').show();
 }
 code_show_err = !code_show_err
} 
$( document ).ready(code_toggle_err);
</script>
To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.''')

# %% [markdown]
# ### Creating Epidemic Model Using SIR

# %%
! pip install ndlib

# %%
import ndlib.models.epidemics as ep

# %%
import ndlib.models.ModelConfig as mc
from ndlib.viz.bokeh.MultiPlot import MultiPlot
from bokeh.io import output_notebook, show
from ndlib.viz.bokeh.DiffusionTrend import DiffusionTrend
output_notebook()
print('On the Left Graphs, we can see user JovialSpeaker87, with a PageRank of score of 0.01177. On the right graphs, we see TraumaticChopsticks461, which is the user with the smallest betweenness centrality measure')
print('Both users were compared by varying the Beta and Gamma parameters to simulate different infectiousness rates')
for i in [0.01, 0.05, 0.1,0.2]:
    model = ep.SIRModel(G)
    # Model Configuration (best user)
    config = mc.Configuration()
    config.add_model_parameter('beta', i)
    config.add_model_parameter('gamma', i/2)
    config.add_model_initial_configuration("Infected", ['JovialSpeaker297'])
    #config.add_model_parameter("fraction_infected", 0.05)
    model.set_initial_status(config)
    iterations = model.iteration_bunch(60)
    trends = model.build_trends(iterations)
    viz = DiffusionTrend(model, trends)
    p = viz.plot(width=400, height=400)
    
    #second model (worst user)
    model = ep.SIRModel(G)
    # Model Configuration
    config = mc.Configuration()
    config.add_model_parameter('beta', i)
    config.add_model_parameter('gamma', i/2)
    config.add_model_initial_configuration("Infected", ['TraumaticChopsticks461'])
    #config.add_model_parameter("fraction_infected", 0.05)
    model.set_initial_status(config)
    iterations = model.iteration_bunch(60)
    trends = model.build_trends(iterations)
    viz2 = DiffusionTrend(model, trends)
    p2 = viz2.plot(width=400, height=400)
    
    vm = MultiPlot()
    vm.add_plot(p)
    vm.add_plot(p2)
    m = vm.plot()
    show(m);

# %% [markdown]
# ### Link Prediction

# %% [markdown]
# The Adamic-Adar Index is a Similarity-Based Method that Hipothesizes that nodes within a Network tend to form links between similar nodes.

# %%
GU = nx.from_pandas_edgelist(edges_users_df, source='source_u', target='target_u', edge_attr='Weight')

# %%
adamic = list(nx.adamic_adar_index(GU))

# %%
df = pd.DataFrame(adamic, columns = ['user1', 'user2', 'adamic_adar_index'])

# %% [markdown]
# Below, we can see the top pairs regarding the Adamic-Adar Index, we can see the top 3 combinations of users involve 'WonderfulPancreas742', which is one of the best ranked nodes according to PageRank in our directed non-weighted graph.

# %%
df.sort_values('adamic_adar_index', ascending = False).head(10)
